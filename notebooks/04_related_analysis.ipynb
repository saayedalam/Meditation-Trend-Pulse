# %%
# Purpose: Import required libraries
import pandas as pd
import numpy as np

# %%
# Purpose: Load cleaned related queries dataset
df_related_cleaned = pd.read_csv("../data/processed/related_queries_cleaned.csv")

# Preview
print("✅ Loaded Shape:", df_related_cleaned.shape)
display(df_related_cleaned.head())
# Out:
# ✅ Loaded Shape: (250, 4)
#       keyword       related_query query_type  popularity_score
# 0  meditation    sleep meditation        top               100
# 1  meditation    meditation music        top                99
# 2  meditation   guided meditation        top                74
# 3  meditation  meditation youtube        top                73
# 4  meditation                yoga        top                55

# %%
# Purpose: Extract top 10 related queries for each keyword
df_top_queries = (
    df_related_cleaned[df_related_cleaned["query_type"] == "top"]
    .sort_values(["keyword", "popularity_score"], ascending=[True, False])
    .groupby("keyword")
    .head(10)
    .reset_index(drop=True)
)

display(df_top_queries)
# Out:
#               keyword                  related_query query_type  \
# 0          breathwork          holotropic breathwork        top
# 1          breathwork            breathwork training        top
# 2          breathwork          breathwork meditation        top
# 3          breathwork             what is breathwork        top
# 4          breathwork             breathwork near me        top
# 5          breathwork             somatic breathwork        top
# 6          breathwork              breathwork online        top
# 7          breathwork            breathwork benefits        top
# 8          breathwork                    breath work        top
# 9          breathwork             breathwork classes        top
# 10  guided meditation               sleep meditation        top
# 11  guided meditation        sleep guided meditation        top
# 12  guided meditation           meditation for sleep        top
# 13  guided meditation    guided meditation for sleep        top
# 14  guided meditation      guided meditation youtube        top
# 15  guided meditation             youtube meditation        top
# 16  guided meditation      guided meditation anxiety        top
# 17  guided meditation  guided meditation for anxiety        top
# 18  guided meditation      guided meditation healing        top
# 19  guided meditation         meditation for anxiety        top
# 20         meditation               sleep meditation        top
# 21         meditation               meditation music        top
# 22         meditation              guided meditation        top
# 23         meditation             meditation youtube        top
# 24         meditation                           yoga        top
# 25         meditation                yoga meditation        top
# 26         meditation             what is meditation        top
# 27         meditation             meditation meaning        top
# 28         meditation         mindfulness meditation        top
# 29         meditation                    mindfulness        top
# 30        mindfulness                     meditation        top
# 31        mindfulness         mindfulness meditation        top
# 32        mindfulness            what is mindfulness        top
# 33        mindfulness            mindfulness meaning        top
# 34        mindfulness             mindfulness que es        top
# 35        mindfulness                mindfulness pdf        top
# 36        mindfulness           mindfulness for kids        top
# 37        mindfulness            mindfulness therapy        top
# 38        mindfulness                        mindful        top
# 39        mindfulness           mindfulness practice        top
# 40         yoga nidra               sleep yoga nidra        top
# 41         yoga nidra             yoga nidra youtube        top
# 42         yoga nidra          nidra yoga meditation        top
# 43         yoga nidra                     meditation        top
# 44         yoga nidra           nidra yoga for sleep        top
# 45         yoga nidra             what is yoga nidra        top
# 46         yoga nidra              yoga nidra script        top
# 47         yoga nidra       cedric michel yoga nidra        top
# 48         yoga nidra            yoga nidra benefits        top
# 49         yoga nidra      yoga nidra ally boothroyd        top
#
#     popularity_score
# 0                100
# 1                 59
# 2                 41
# 3                 36
# 4                 32
# 5                 28
# 6                 22
# 7                 22
# 8                 16
# 9                 16
# 10               100
# 11                95
# 12                34
# 13                34
# 14                33
# 15                31
# 16                22
# 17                19
# 18                19
# 19                18
# 20               100
# 21                99
# 22                74
# 23                73
# 24                55
# 25                53
# 26                43
# 27                35
# 28                33
# 29                33
# 30               100
# 31                95
# 32                43
# 33                35
# 34                28
# 35                26
# 36                23
# 37                22
# 38                22
# 39                22
# 40               100
# 41                82
# 42                64
# 43                63
# 44                63
# 45                28
# 46                19
# 47                15
# 48                15
# 49                14

# %%
# Purpose: Extract top 10 rising queries for each keyword
df_rising_queries = (
    df_related_cleaned[df_related_cleaned["query_type"] == "rising"]
    .sort_values(["keyword", "popularity_score"], ascending=[True, False])
    .groupby("keyword")
    .head(10)
    .reset_index(drop=True)
)

display(df_rising_queries)
# Out:
#               keyword                                      related_query  \
# 0          breathwork                             gary brecka breathwork
# 1          breathwork                         somatic release breathwork
# 2          breathwork                               othership breathwork
# 3          breathwork                                  breathwork sessie
# 4          breathwork                                      9d breathwork
# 5          breathwork                                  owaken breathwork
# 6          breathwork                                witality breathwork
# 7          breathwork                         somatic breathwork near me
# 8          breathwork                                 breathwork o que é
# 9          breathwork                            breathwork class london
# 10  guided meditation  jason stephenson guided meditation sleep 30 mi...
# 11  guided meditation     guided meditation for anxiety and overthinking
# 12  guided meditation      best guided sleep meditation jason stephenson
# 13  guided meditation       free guided meditation for sleep and anxiety
# 14  guided meditation                     joe dispenza guided meditation
# 15  guided meditation            guided meditation for anxiety and sleep
# 16  guided meditation                         ram dass guided meditation
# 17  guided meditation                        15 minute guided meditation
# 18  guided meditation                          what is guided meditation
# 19  guided meditation                 jason stephenson guided meditation
# 20         meditation                        anika henkelmann meditation
# 21         meditation                         pipersong meditation chair
# 22         meditation                          replica matcha meditation
# 23         meditation                                  matcha meditation
# 24         meditation                    joe dispenza morning meditation
# 25         meditation                          boho beautiful meditation
# 26         meditation                           mady morrison meditation
# 27         meditation                  mindful movement sleep meditation
# 28         meditation                          meditation centre near me
# 29         meditation                              peter beer meditation
# 30        mindfulness                          mindfulness para asesinos
# 31        mindfulness              mindfulness que es y como se práctica
# 32        mindfulness                                mindfulness artinya
# 33        mindfulness                                 mindfulness adalah
# 34        mindfulness                             mindfulness traducción
# 35        mindfulness                                  mindfulness cos'è
# 36        mindfulness                                  mindfulness co to
# 37        mindfulness                      meditación guiada mindfulness
# 38        mindfulness                       mindfulness meaning in hindi
# 39        mindfulness                            mindfulness significato
# 40         yoga nidra                          yoga nidra ally boothroyd
# 41         yoga nidra                                    yoga nidra nsdr
# 42         yoga nidra                                               nsdr
# 43         yoga nidra                            anabel otero yoga nidra
# 44         yoga nidra                    yoga nidra ally boothroyd sleep
# 45         yoga nidra                                non sleep deep rest
# 46         yoga nidra                                      nsdr huberman
# 47         yoga nidra                              kelly boys yoga nidra
# 48         yoga nidra                                huberman yoga nidra
# 49         yoga nidra                                    andrew huberman
#
#    query_type  popularity_score
# 0      rising             31500
# 1      rising             30450
# 2      rising             25650
# 3      rising             19950
# 4      rising             11100
# 5      rising              3250
# 6      rising              2850
# 7      rising               900
# 8      rising               800
# 9      rising               750
# 10     rising              2650
# 11     rising              1750
# 12     rising               950
# 13     rising               450
# 14     rising               190
# 15     rising               130
# 16     rising               130
# 17     rising               110
# 18     rising               110
# 19     rising               110
# 20     rising             10850
# 21     rising              9500
# 22     rising              6700
# 23     rising              2300
# 24     rising               750
# 25     rising               700
# 26     rising               650
# 27     rising               600
# 28     rising               500
# 29     rising               300
# 30     rising             18250
# 31     rising              3050
# 32     rising               950
# 33     rising               600
# 34     rising               500
# 35     rising               450
# 36     rising               350
# 37     rising               300
# 38     rising               250
# 39     rising               250
# 40     rising            131050
# 41     rising             65350
# 42     rising             65300
# 43     rising             27900
# 44     rising             27700
# 45     rising             16150
# 46     rising             15400
# 47     rising             11400
# 48     rising              8200
# 49     rising              8150

# %%
# Purpose: Count how many keywords each related query appears under
query_keyword_counts = (
    df_related_cleaned.groupby("related_query")["keyword"]
    .nunique()
    .reset_index(name="num_keywords")
    .sort_values(by="num_keywords", ascending=False)
)

# Preview queries that appear across multiple keywords
display(query_keyword_counts.head(15))
# Out:
#                related_query  num_keywords
# 133   mindfulness meditation             3
# 114              mindfulness             2
# 91                meditation             2
# 105         meditation music             2
# 99    meditation for anxiety             2
# 100     meditation for sleep             2
# 174         sleep meditation             2
# 150   mindfulness traducción             1
# 149      mindfulness therapy             1
# 148   mindfulness techniques             1
# 152     mindfulness training             1
# 153         mindfulness yoga             1
# 154          mindfulness คือ             1
# 155       morning breathwork             1
# 147  mindfulness significato             1

# %%
# Filter for queries that appear in 2 or more keywords
shared_queries = query_keyword_counts[query_keyword_counts["num_keywords"] >= 2]

# Merge to get full info for shared queries
df_shared_queries = (
    df_related_cleaned.merge(shared_queries, on="related_query", how="inner")
    .sort_values(by=["num_keywords", "related_query", "keyword"], ascending=[False, True, True])
    .reset_index(drop=True)
)

# Preview
display(df_shared_queries.head(15))
# Out:
#               keyword           related_query query_type  popularity_score  \
# 0   guided meditation  mindfulness meditation        top                10
# 1          meditation  mindfulness meditation        top                33
# 2         mindfulness  mindfulness meditation        top                95
# 3         mindfulness              meditation        top               100
# 4          yoga nidra              meditation        top                63
# 5   guided meditation  meditation for anxiety        top                18
# 6   guided meditation  meditation for anxiety     rising                80
# 7          meditation  meditation for anxiety        top                17
# 8   guided meditation    meditation for sleep        top                34
# 9          meditation    meditation for sleep        top                31
# 10  guided meditation        meditation music        top                 8
# 11         meditation        meditation music        top                99
# 12  guided meditation             mindfulness        top                 9
# 13         meditation             mindfulness        top                33
# 14  guided meditation        sleep meditation        top               100
#
#     num_keywords
# 0              3
# 1              3
# 2              3
# 3              2
# 4              2
# 5              2
# 6              2
# 7              2
# 8              2
# 9              2
# 10             2
# 11             2
# 12             2
# 13             2
# 14             2

# %%
# 💾 Save Top 10 related queries per keyword (type: top)
df_top_queries.to_csv("../data/processed/related_queries_top10.csv", index=False)

# 💾 Save Top 10 rising related queries per keyword (type: rising)
df_rising_queries.to_csv("../data/processed/related_queries_rising10.csv", index=False)

# 💾 Save related queries that appear across 2 or more keywords
df_shared_queries.to_csv("../data/processed/related_queries_shared.csv", index=False)

# 💾 Save summary: number of keywords each related query appears in
query_keyword_counts.to_csv("../data/processed/related_query_keyword_counts.csv", index=False)
